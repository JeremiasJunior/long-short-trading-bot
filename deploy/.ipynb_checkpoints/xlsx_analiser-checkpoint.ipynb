# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sb
import random
import os
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from scipy.optimize import rosen, differential_evolution
sb.set()

os.chdir('..')

# %%
name = 'forest[(10, 150), (0, 5), (-5, 0), (-1, 0), (0, 1), (700, 3000), (25, 50), (-300, 0), (50, 250)]b962_l5502522roiloss1000305_2018.12.18x2019.12.31_full.xls'
data = pd.read_excel(name)
print(data.keys())
print(sum(data['profit']))
# Out:
# Index(['Unnamed: 0', 'type', 'date_open', 'date_close', 'x_name', 'y_name',
#        'x_type', 'y_type', 'y_openprice', 'y_closeprice', 'x_openprice',
#        'x_closeprice', 'x_volume', 'y_volume', 'profit', 'status', 's_spread',
#        'l_spread', 'tp_short', 'tp_long', 'tp_return', 's_return', 's_number',
#        'period', 'count', 'days', 'min_count'],
#       dtype='object')
# 3440.2747524752413

# %%
expo = data['x_openprice']*data['x_volume'] + data['y_openprice']*data['y_volume']

'''
for row_index in range(len(new_df)):
    if(new_df[row_index] < -100):
        new_df[row_index] = -100
    if(new_df[row_index] >300):
        new_df[row_index] = 300
        
print((new_df), sum(new_df))
'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y_ovolume'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-72ba8709c224> in <module>
# ...

# %%
plt.plot(np.cumsum(new_df))

# %%
plt.scatter( data['profit'],data['min_count'])

# %%
x_return_np = np.array(x_return_list)
y_return_np = np.array(y_return_list)

return_np = x_return_np + y_return_np
data['profit'] = return_np

# %%
data.to_excel(name)

# %%
sum(data['profit'])

# %%
plt.plot(np.cumsum(data['profit']))
